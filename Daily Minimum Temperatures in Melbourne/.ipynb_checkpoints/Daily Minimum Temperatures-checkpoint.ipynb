# %%
# Importing libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras import losses
from keras.layers import Dense
import math

# %%
data = pd.read_csv('daily-minimum-temperatures-in-me.csv')
data.head(10)
# Out:
#          Date  Temperatures
# 0  1981-01-01          20.7
# 1  1981-01-02          17.9
# 2  1981-01-03          18.8
# 3  1981-01-04          14.6
# 4  1981-01-05          15.8
# 5  1981-01-06          15.8
# 6  1981-01-07          15.8
# 7  1981-01-08          17.4
# 8  1981-01-09          21.8
# 9  1981-01-10          20.0

# %%
'Linhas: {} | Colunas: {}'.format(data.shape[0], data.shape[1])
# Out:
# 'Linhas: 3650 | Colunas: 2'

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
data = pd.read_csv('daily-minimum-temperatures-in-me.csv', parse_dates=['Date'], date_parser=dateparse)

# %%
data.plot(x='Date', y='Temperatures', figsize=(13, 9))
plt.grid(True)
plt.show()

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if (end_ix > len(sequence)-1): break
        
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
        
    return np.array(X), np.array(y)

# %%
n_steps = 30

# %%
X, y = split_sequence(sequence=data['Temperatures'], n_steps=n_steps)

# %%
print(len(X))

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)
X_train = X[:math.floor(len(X)*0.3)]
X_test = X[math.floor(len(X)*0.3):]
y_train = y[:math.floor(len(X)*0.3)]
y_test = y[math.floor(len(X)*0.3):]

# %%
mlp = Sequential()

mlp.add(
    Dense(
        units=2,
        activation='relu',
        kernel_initializer='random_normal',
        input_dim=n_steps
    )
)

# %%
mlp.add(
    Dense(
        units=3,
        activation='relu',
        kernel_initializer='random_normal'
    )
)

# %%
mlp.add(
    Dense(
        units=1,
        activation='relu',
        kernel_initializer='random_normal'
    )
)

# %%
mlp.compile(optimizer='adam',
            loss=losses.mean_absolute_percentage_error,
            metrics=['accuracy']
            )

# %%
model = mlp.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-62c1f98c9922> in <module>
# ----> 1 model = mlp.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
#
# ~/fundacao/fundacao/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ~/fundacao/fundacao/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~/fundacao/fundacao/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected dense_7_input to have shape (3,) but got array with shape (30,)

# %%
plt.title('Treino')
plt.grid(True)
plt.plot(model.history['acc'])
plt.show()

# %%
plt.title('Teste')
plt.grid(True)
plt.plot(model.history['val_acc'])
plt.show()

# %%
model = mlp.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))

# %%
plt.title('Treino')
plt.grid(True)
plt.plot(model.history['acc'])
plt.show()

# %%
plt.title('Teste')
plt.grid(True)
plt.plot(model.history['val_acc'])
plt.show()

# %%
X, y = split_sequence(sequence=data['Temperatures'], n_steps=7)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
mlp = Sequential()

mlp.add(
    Dense(
        units=2,
        activation='relu',
        kernel_initializer='random_normal',
        input_dim=7
    )
)

mlp.add(
    Dense(
        units=3,
        activation='relu',
        kernel_initializer='random_normal'
    )
)

mlp.add(
    Dense(
        units=1,
        activation='relu',
        kernel_initializer='random_normal'
    )
)

# %%
mlp.compile(optimizer='adam',
            loss=losses.mean_absolute_percentage_error,
            metrics=['accuracy']
    )

# %%
model = mlp.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))

# %%
plt.title('Treino')
plt.grid(True)
plt.plot(model.history['acc'])
plt.show()

# %%
plt.title('Teste')
plt.grid(True)
plt.plot(model.history['val_acc'])
plt.show()
